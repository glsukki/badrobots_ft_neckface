# %%
import os
import pandas as pd

# %%
neckface_numerical_preds_path = "../data/neckface_dataset/pred_outputs/all_participant_preds.csv"
nf_num_preds_df = pd.read_csv(neckface_numerical_preds_path)
nf_num_preds_df
# Out:
#        participant_id stimulus_video_name  class_label pred_type  \
# 0                   1                 ch1            0    survey
# 1                   1                 ch1            0    survey
# 2                   1                 ch1            0    survey
# 3                   1                 ch1            0    survey
# 4                   1                 ch1            0    survey
# ...               ...                 ...          ...       ...
# 97905               9                fr10            1    survey
# 97906               9                fr10            1    survey
# 97907               9                fr10            1    survey
# 97908               9                fr10            1    survey
# 97909               9                fr10            1    survey
#
#                   0           1           2           3          4          5  \
# 0      1.688658e+09  166.600357  213.580185  367.162781  -5.021532  -7.206392
# ...

# %%
nf_num_preds_df.shape
# Out:
# (97910, 61)

# %%
class_labels = nf_num_preds_df["class_label"].value_counts().to_dict()
class_labels
# Out:
# {0: 56721, 1: 41189}
